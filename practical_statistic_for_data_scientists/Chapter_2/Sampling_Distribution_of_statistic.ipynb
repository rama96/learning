# %%
# !kaggle datasets download subhamjain/loan-prediction-based-on-customer-behavior -f "Training Data.csv" --unzip -o -p "/Users/ramamurthi/Pet_Projects/learning/DATA/loan_prediction/" 
# !unzip "/Users/ramamurthi/Pet_Projects/learning/DATA/loan_prediction/Training%20Data.csv.zip" -d "/Users/ramamurthi/Pet_Projects/learning/DATA/loan_prediction/"

# %%
import kaggle
from easy_ml import create_directory_if_not_exists
from helpers import DIR_KAGGLE 
from helpers.kaggle_utils import download_kaggle_datasets  
import os
import pandas as pd
import seaborn as sns

# %%
dir_path = download_kaggle_datasets("subhamjain/loan-prediction-based-on-customer-behavior","LOAN_PREDICTION")
os.listdir(dir_path)
# Out:
# ['Training Data.csv', 'Sample Prediction Dataset.csv', 'Test Data.csv']

# %%
filepath = dir_path.joinpath('Training Data.csv')
df = pd.read_csv(filepath)
df.columns = [i.lower() for i in df.columns]
df
# Out:
#             id   income  age  experience married/single house_ownership car_ownership           profession                 city           state  current_job_yrs  current_house_yrs  risk_flag
# 0            1  1303834   23           3         single          rented            no  Mechanical_engineer                 Rewa  Madhya_Pradesh                3                 13          0
# 1            2  7574516   40          10         single          rented            no   Software_Developer             Parbhani     Maharashtra                9                 13          0
# 2            3  3991815   66           4        married          rented            no     Technical_writer            Alappuzha          Kerala                4                 10          0
# 3            4  6256451   41           2         single          rented           yes   Software_Developer          Bhubaneswar          Odisha                2                 12          1
# ...

# %%
print(df.dtypes)
df.describe()
# Out:
# id                    int64
# income                int64
# age                   int64
# experience            int64
# married/single       object
# house_ownership      object
# car_ownership        object
# profession           object
# city                 object
# state                object
# current_job_yrs       int64
# current_house_yrs     int64
# risk_flag             int64
# dtype: object
#              id     income       age  experience  current_job_yrs  current_house_yrs  risk_flag
# count 252000.00  252000.00 252000.00   252000.00        252000.00          252000.00  252000.00
# mean  126000.50 4997116.67     49.95       10.08             6.33              12.00       0.12
# std    72746.28 2878311.01     17.06        6.00             3.65               1.40       0.33
# min        1.00   10310.00     21.00        0.00             0.00              10.00       0.00
# 25%    63000.75 2503015.00     35.00        5.00             3.00              11.00       0.00
# ...

# %%
# Complete data
complete_data = pd.DataFrame({'income':df['income'] , 'type':'data'})

# Picking 1000 samples at random
sample_data = pd.DataFrame({'income':df['income'].sample(1000) , 'type':'sample_data'})

# Picking mean of samples of 5 1000 times
sample_data_05 = pd.DataFrame({'income': [df['income'].sample(5).mean() for _ in range(1000)] , 'type':'mean_5'})

# Picking mean of samples of 20 1000 times
sample_data_20 = pd.DataFrame({'income':df['income'].sample(20) , 'type':'mean_20'})

# Picking mean of samples of 20 1000 times
sample_data_50 = pd.DataFrame({'income':df['income'].sample(20) , 'type':'mean_50'})


results = pd.concat([complete_data , sample_data , sample_data_05 , sample_data_20 , sample_data_50])
